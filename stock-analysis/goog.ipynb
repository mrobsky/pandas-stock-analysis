# %%
import pandas as pd
import pandas_datareader.data as pdr
import datetime
import yfinance as yf
import matplotlib.pyplot as plt

# %%
start = datetime.datetime(2022,1,1)
end = datetime.datetime(2023,1,1)
yf.pdr_override()

# %%
google = pdr.get_data_yahoo("GOOGL",start=start,end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
google.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-01-03 00:00:00-05:00  145.054993  145.850998  143.712997  144.991501
# 2022-01-04 00:00:00-05:00  145.395996  146.485001  143.716507  144.399506
# 2022-01-05 00:00:00-05:00  144.419998  144.499496  137.688004  137.774994
# 2022-01-06 00:00:00-05:00  136.998505  139.940002  136.558502  137.747498
# 2022-01-07 00:00:00-05:00  138.145493  138.448502  135.766495  137.016998
#
#                             Adj Close    Volume
# Date
# 2022-01-03 00:00:00-05:00  144.991501  28646000
# 2022-01-04 00:00:00-05:00  144.399506  28400000
# 2022-01-05 00:00:00-05:00  137.774994  54618000
# 2022-01-06 00:00:00-05:00  137.747498  37348000
# 2022-01-07 00:00:00-05:00  137.016998  29760000

# %%
google['Open'].plot(label = "Google Open Price", figsize=(15,7))
google['Close'].plot(label = "Google Close Price")
plt.legend()
plt.title('Google stock price')
plt.ylabel('Price $')

plt.show()

# %%
google['Volume'].plot(label = 'Volume')
# Out:
# <AxesSubplot: xlabel='Date'>
